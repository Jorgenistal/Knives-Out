# %% [markdown]
# <span class="girk">REFERENCES</span>
#
# The entire game has been created in-house and is based on the 2019 film Knives Out. All clues and events have been taken from viewing the movie.
#
# <span class="girk">BUGS OR COMMENTS</span>
#
# - No variable has been carried over from one stage to another, following the requirements. But it is true that 3 global variables have been created. According to the requirements it is recommended not to use them (so we can use them).The reason why they have been created is because in stage_1_1 three people have to be interrogated. For each interrogation I have created a function because it was more comfortable. Then the reason for the global variable is to avoid the user to interrogate the same person 2 or 3 times. So each time the user has chosen a person, it has been saved in a global variable so that it could be taken into the next function, although always being part of the same stage. In addition, at the end of the stage (stage_1_2) the user is told which persons he/she has questioned.
#
# - The first input in the def stage_1_1 (): has been put there because if you just hit print(the information inside the prompt), sometimes the question of who you want to interrogate first and then the little introduction that we are starting appears first.
#
# - In the last stage there is a possible improvement. In case the user enters a name that is not a suspect in the question who hired you, it will not count as an attempt, because there is a conditional statement that will tell you that it is not an option and will return you to the question. The problem comes in the second question. Because if you typed correctly the first name but is the wrong answer, regardless of whether the second is misspelled, as the other option is wrong, but it is spelled correctly, it will count as an error. So technically it is not a bug, but it could be improved. But it has been foreseen that in case the first option is the correct one, and you misspell the second one, it will not count as an attempt and will tell you that it is not an option.

# %% [markdown]
#    ______________________________________________________INTRODUCTION______________________________________________________
#
# You are the private detective Benoit Blanc and you are on the scene of the murder with several unknowns to solve. First of all, you do not know who contacted you, and you have to find out who it was.
#
# On the other hand, you have been hired to find out who the murderer of Harlan Thrombey is. Harlan turned up this morning dead and with cuts on his neck. It is possible that it was a suicide, but you do not have all the evidence, so you are going to have to interrogate certain people and find out what happened.
#
# We also know that yesterday was his birthday and he celebrated it in the afternoon with all his family and closest people, so everyone close to him in one way or another was close to the dead man in the hours before the event.
#
# It is BASED on the movie, it does not mean that the outcome has to be the same. So prove that you are a good detective and find the killer and who hired you.

# %%
# I have created a list that includes sublists of each of the suspects. 
# That is, their full names and the letter that corresponds to them.

suspects = [["a", "Donna Thrombey"], ["b", "Joni Thrombey"], ["c", "Walt Thrombey"], ["d", "Lynda Drysdale"], 
           ["e", "Richard Drysdale"], ["f", "Hugh Drysdale"], ["g", "Harlan Thrombey"], ["h", "Marta Cabrera"],
           ["i", "Meg Thrombey"], ["j", "Wanetta Thrombey"]
           ]



# HERE THE FUNCTION OF STAGE 1.1 IS DEFINED.
# In this first part you can question three people, entering their names. So that 
# a user cannot choose the same people, a global variable has been created for the answer entered. 
# The variable will not be passed between different stages but it will be in different functions 
# since I have created a different function for each question.
    
def stage_1_1 ():
    input( prompt = f"""Inspector Benoit Blanc you will be 
able to interrogate 3 of the following suspects.
    
    """)
    # for loop created so that before each user decides what to ask he/she is shown 
    #the possible people he/she can ask that have been set in the list created at the beginning. 
    
    for letter, suspect in suspects:
        print(suspect)
    
    
    # I have made it global because it will also be used in the choice_2 and choice_3 function 
    # so that a user cannot question the same person twice.
    global answer_1
    answer_1 = input(prompt = f""" 
    Who do you want to question first?
    (enter their first name)
    
    """)
    
    # regardless of what the user enters, the input will be converted to lower case.
    answer_1 = answer_1.lower()
    
    
    # information to be disclosed in case the user decides to question donna    
    if "donna" in answer_1:
        print(f""" 
        
        I'm not interested in this murder and even less in incriminating someone 
        in my family... But if someone stabbed my father had to be Hugh (for me he  
        is not family) or Marta (she is not family at all). 
            
            """)
        # what the user has answered will be transformed only to donna because then 
        #it will be checked in choice_2 and choice_3, if that donna is within the following answers.    
        answer_1 = "donna"
        choice_2()
    
    # information to be disclosed in case the user decides to question joni
    elif "joni" in answer_1:
        print(f""" 
            
            Harlan helped me start my company and pay for Meg's college. I took advantage of 
            the payments because I made sure that when I got paid, the amount was double what was needed. 
            But come on, whether Harlan knew it or not, it gives me no reason to kill him.
            
            """)
        
        # what the user has answered will be transformed only to joni because then 
        #it will be checked in choice_2 and choice_3, if that joni is within the following answers.
        
        answer_1 = "joni"
        choice_2()
        
    # information to be disclosed in case the user decides to question walt    
    elif "walt" in answer_1:
        print(f""" 
        
        I am hurt with my father because he was going to fired me from his advertising company.  
        But I loved him anyway and I would never kill him. Besides, I have always been he needed me, there are 
        others who are not even family, like Marta, for example. Have you questioned her yet?        
        
        """)
        
        # what the user has answered will be transformed only to walt because then 
        #it will be checked in choice_2 and choice_3, if that walt is within the following answers.
        
        answer_1 = "walt"
        choice_2()
        
    # information to be disclosed in case the user decides to question lynda    
    elif "lynda" in answer_1:
        print(f""" 
        
            My relationship with my father was peculiar, we showed our love in a 
            different way than my brothers did. Although it also happens to my son Hugh,
            since they were always arguing. 
            
            """)
        
        # what the user has answered will be transformed only to lynda because then 
        #it will be checked in choice_2 and choice_3, if that lynda is within the following answers.
        
        
        answer_1 = "lynda"
        choice_2()
        
    # information to be disclosed in case the user decides to question richard    
    elif "richard" in answer_1:
        print(f""" 
        
        I want to be frank Benoit, Harlan had discovered that I was cheating on his 
        daughter and told me that either I would tell him, or he would. But I would 
        never hurt Harlan, you can ask Marta she knows almost everything. 
            
            """)
        
        # what the user has answered will be transformed only to richard because then 
        #it will be checked in choice_2 and choice_3, if that richard is within the following answers.
        
        answer_1 = "richard"
        choice_2()
        
    # information to be disclosed in case the user decides to question hugh    
    elif "hugh" in answer_1:
        print(f""" 
        
            I am the least liked here and I know. But what nobody has told you is that none of 
            the family is part of Harlan's will anymore, and everything will go to Marta, 
            so here the person who had the most to gain was Marta. 
            
            """)
        
        # what the user has answered will be transformed only to hugh because then 
        # it will be checked in choice_2 and choice_3, if that hugh is within the following answers.
        
        answer_1 = "hugh"
        choice_2()
        
    # the user is given the option to question Harlan to see if he is attentive. 
    # After reminding him that he is the dead one, he will send him again to choose someone he can interrogate.     
    elif "harlan" in answer_1:
        print(f""" 
        
        I'm dead, I can't give you any clues!!! 
            
            """)
            
        answer_1 = "harlan"
        stage_1_1()
        
    # information to be disclosed in case the user decides to question marta    
    elif "marta" in answer_1:
        print(f""" 
        
        I didn't try to kill Harlan but it was my fault. I unintentionally inject 
        Harlan 100 mg from the morphine bottle, instead of Toradol. I didn't have 
        the antidote that is usually in the bag....
            
            """)
        
        # what the user has answered will be transformed only to marta because then 
        #it will be checked in choice_2 and choice_3, if that marta is within the following answers.
        
        answer_1 = "marta"
        choice_2()
        
    # information to be disclosed in case the user decides to question meg   
    elif "meg" in answer_1:
        print(f""" 
        
        What can I say? To be honest I don't see my mother Joni killing Harlan 
        just for the college money. As for Marta she is a nice girl, but maybe
        she would be able to kill Harlan, although Hugh may also be able. 
            
            """)
        
        # what the user has answered will be transformed only to meg because then 
        #it will be checked in choice_2 and choice_3, if that meg is within the following answers.
        
        
        answer_1 = "meg"
        choice_2()
        
    # information to be disclosed in case the user decides to question wanetta    
    elif "wanetta" in answer_1:
        print(f""" 
        
        Even though I am an older woman I know what I saw the night of the murder.
        In the afternoon I saw Hugh sneak up and down the window. Also, that same 
        night Martha did the same thing. I don't know the motive of both, but I saw what I saw.
            
            """)
        
        # what the user has answered will be transformed only to wanetta because then 
        #it will be checked in choice_2 and choice_3, if that wanetta is within the following answers.
        
        answer_1 = "wanetta"
        choice_2()
    
    # This is a backdoor that if you enter in any answer the title of the movie 
    # tells you the solution and sends you directly to where you have to solve the murder. 
    # This is not in the instructions and therefore is not taken into account as a possible resolution in a short time. 
    # Even so, I thought it was a good idea to include it in case someone thought of including the title of the movie. 
    elif "knives out" in answer_1:
        print("You have been hired by Hugh Drysdale and Harlan committed suicide. ")
        stage_3()
    
    # If the user does not enter any of the names displayed on the screen, 
    # he will be sent back to the question of whom he wants to question.
    else: 
        print(f""" 
        
        The option entered is not valid, please re-enter a valid option.
        """)
        
        
        stage_1_1()


# HERE THE FUNCTION OF CHOICE_2 IS DEFINED.      
        
def choice_2 ():
   
    
    
    # for loop created so that before each user decides what to ask he/she is shown 
    #the possible people he/she can ask that have been set in the list created at the beginning.
    for letter, suspect in suspects:
        print(suspect)
    
    # I have made it global because it will also be used in the choice_3 function 
    # so that a user cannot question the same person twice.
    global answer_2
    answer_2 = input(prompt = f""" 
    Who do you want to be the second lucky person you will question??
    (enter their first name)
    
    """)
    
    # regardless of what the user enters, the input will be converted to lower case.
    answer_2 = answer_2.lower()
    
    
    # first I create an if statement so that the user cannot question the same person twice. 
    # To do this I check that the choice_1 that was converted only with the name of the user interrogated, 
    # is not inside the choice_2.
    if answer_1 in answer_2:
        print(f"""
        
        You have already questioned that person, please show that you 
              are a good detective and choose another one.
              """)
        
        choice_2()
    # once I check that the user isn´t questioning the same person, the second hint is released    
    else:
        
        # information to be disclosed in case the user decides to question donna 
        if "donna" in answer_2:
            print(f""" 
            
        I'm not interested in this murder and even less in incriminating someone 
        in my family... But if someone stabbed my father had to be Hugh (for me he  
        is not family) or Marta (she is not family at all).
            
            """)
            
            # what the user has answered will be transformed only to donna because then 
            # it will be checked in choice_3, if donna is within the following answers.
            answer_2 = "donna"
            choice_3()
        
        # information to be disclosed in case the user decides to question joni
        elif "joni" in answer_2:
            print(f""" 
            
            Harlan helped me start my company and pay for Meg's college. I took advantage of 
            the payments because I made sure that when I got paid, the amount was double what was needed. 
            But come on, whether Harlan knew it or not, it gives me no reason to kill him.
            
            """)
            
            # what the user has answered will be transformed only to joni because then 
            # it will be checked in choice_3, if joni is within the following answers.
            answer_2 = "joni"
            choice_3()
        
        # information to be disclosed in case the user decides to question walt
        elif "walt" in answer_2:
            print(f""" 
            
        I am hurt with my father because he was going to fired me from his advertising company.  
        But I loved him anyway and I would never kill him. Besides, I have always been he needed me, there are 
        others who are not even family, like Marta, for example. Have you questioned her yet? 
        
            """)
            
            # what the user has answered will be transformed only to walt because then 
            # it will be checked in choice_3, if walt is within the following answers.
            answer_2 = "walt"
            choice_3()
        
        # information to be disclosed in case the user decides to question lynda
        elif "lynda" in answer_2:
            print(f""" 
            
            My relationship with my father was peculiar, we showed our love in a 
            different way than my brothers did. Although it also happens to my son Hugh,
            since they were always arguing. 
            
            """)
            
            # what the user has answered will be transformed only to lynda because then 
            # it will be checked in choice_3, if lynda is within the following answers.
            answer_2 = "lynda"
            choice_3()
        
        # information to be disclosed in case the user decides to question richard
        elif "richard" in answer_2:
            print(f""" 
            
        I want to be frank Benoit, Harlan had discovered that I was cheating on his 
        daughter and told me that either I would tell him, or he would. But I would 
        never hurt Harlan, you can ask Marta she knows almost everything.
            
            """)
            
            # what the user has answered will be transformed only to richard because then 
            # it will be checked in choice_3, if richard is within the following answers.
            answer_2 = "richard"
            choice_3()
        
        # information to be disclosed in case the user decides to question hugh
        elif "hugh" in answer_2:
            print(f""" 
            
            I am the least liked here and I know. But what nobody has told you is that none of 
            the family is part of Harlan's will anymore, and everything will go to Marta, 
            so here the person who had the most to gain was Marta.            
            
            """)
            
            # what the user has answered will be transformed only to hugh because then 
            # it will be checked in choice_3, if hugh is within the following answers.
            answer_2 = "hugh"
            choice_3()
        
        # the user is given the option to question Harlan to see if he is attentive. 
        # After reminding him that he is the dead one, he will send him again to choose someone he can interrogate.
        elif "harlan" in answer_2:
            print(f""" 
            
            I'm dead, I can't give you any clues!!! 
            
            """)
            
            answer_2 = "harlan"
            choice_2()
        
        # information to be disclosed in case the user decides to question marta
        elif "marta" in answer_2:
            print(f""" 
            
        I didn't try to kill Harlan but it was my fault. I unintentionally inject 
        Harlan 100 mg from the morphine bottle, instead of Toradol. I didn't have 
        the antidote that is usually in the bag....

            """)
            
            # what the user has answered will be transformed only to marta because then 
            # it will be checked in choice_3, if marta is within the following answers.
            answer_2 = "marta"
            choice_3()
        
        # information to be disclosed in case the user decides to question meg
        elif "meg" in answer_2:
            print(f""" 
        
        What can I say? To be honest I don't see my mother Joni killing Harlan 
        just for the college money. As for Marta she is a nice girl, but maybe
        she would be able to kill Harlan, although Hugh may also be able. 
            
            """)
            
            # what the user has answered will be transformed only to meg because then 
            # it will be checked in choice_3, if meg is within the following answers.
            answer_2 = "meg"
            choice_3()
        
        # information to be disclosed in case the user decides to question wanetta
        elif "wanetta" in answer_2:
            print(f""" 
        
        Even though I am an older woman I know what I saw the night of the murder.
        In the afternoon I saw Hugh sneak up and down the window. Also, that same 
        night Martha did the same thing. I don't know the motive of both, but I saw what I saw.
            
            """)
            
            # what the user has answered will be transformed only to wanetta because then 
            # it will be checked in choice_3, if wanetta is within the following answers.
            answer_2 = "wanetta"
            choice_3()
        
        # This is a backdoor that if you enter in any answer the title of the movie 
        # tells you the solution and sends you directly to where you have to solve the murder. 
        # This is not in the instructions and therefore is not taken into account as a possible resolution in a short time. 
        # Even so, I thought it was a good idea to include it in case someone thought of including the title of the movie.
        elif "knives out" in answer_2:
            print("You have been hired by Hugh Drysdale and Harlan committed suicide. ")
            stage_3()
        
        # If the user does not enter any of the names displayed on the screen, 
        # he will be sent back to the question of whom he wants to question.
        else: 
            print(f""" 
        
            The option entered is not valid, please re-enter a valid option.""")
        
        
            choice_2()

# HERE THE FUNCTION OF CHOICE_3 IS DEFINED.     
        
def choice_3 ():
   
    
    
    # for loop created so that before each user decides what to ask he/she is shown 
    #the possible people he/she can ask that have been set in the list created at the beginning.
    for letter, suspect in suspects:
        print(suspect)
    
    # I have made it global because it will also be used in the choice_2 and choice_3 function 
    # so that a user cannot question the same person twice. and also because before the end of 
    # the stage the user will be shown the three people he/she has questioned. 
    global answer_3
    answer_3 = input(prompt = f""" You can only question one other person. Think carefully before deciding.
    (enter their first name)
    
    
    """)
    
    # regardless of what the user enters, the input will be converted to lower case.
    answer_3 = answer_3.lower()
    
    # first I create an if statement so that the user cannot question the same person twice. 
    # To do this I check that the choice_1 that was converted only with the name of the user interrogated, 
    # is not inside the choice_2 or choice_3.
    if answer_1 in answer_3 or answer_2 in answer_3:
        print(f"""
        
        You have already questioned that person, please show that you 
              are a good detective and choose another one.
              """)
        
        choice_3()
    
    # once I check that the user isn´t questioning the same person, the third hint is released
    else:
        
        # information to be disclosed in case the user decides to question donna 
        if "donna" in answer_3:
            print(f""" 
            
        I'm not interested in this murder and even less in incriminating someone 
        in my family... But if someone stabbed my father had to be Hugh (for me he  
        is not family) or Marta (she is not family at all).
            
            """)
            
            # what the user has answered will be transformed only to donna because then it will be used 
            # at the end of stage 1 to send a message to the user of the people you have interrogated. 
            answer_3 = "donna"
            stage_1_2()
        
        # information to be disclosed in case the user decides to question joni
        elif "joni" in answer_3:
            print(f""" 
             
            Harlan helped me start my company and pay for Meg's college. I took advantage of 
            the payments because I made sure that when I got paid, the amount was double what was needed. 
            But come on, whether Harlan knew it or not, it gives me no reason to kill him.
            
            """)
            
            # what the user has answered will be transformed only to joni because then it will be used 
            # at the end of stage 1 to send a message to the user of the people you have interrogated. 
            answer_3 = "joni"
            stage_1_2()
        
        # information to be disclosed in case the user decides to question walt
        elif "walt" in answer_3:
            print(f""" 
            
        I am hurt with my father because he was going to fired me from his advertising company.  
        But I loved him anyway and I would never kill him. Besides, I have always been he needed me, there are 
        others who are not even family, like Marta, for example. Have you questioned her yet? 
        
        """)
            
            # what the user has answered will be transformed only to walt because then it will be used 
            # at the end of stage 1 to send a message to the user of the people you have interrogated. 
            answer_3 = "walt"
            stage_1_2()
        
        # information to be disclosed in case the user decides to question lynda
        elif "lynda" in answer_3:
            print(f""" 
            
            My relationship with my father was peculiar, we showed our love in a 
            different way than my brothers did. Although it also happens to my son Hugh,
            since they were always arguing. 
            
            """)
            
            # what the user has answered will be transformed only to lynda because then it will be used 
            # at the end of stage 1 to send a message to the user of the people you have interrogated. 
            answer_3 = "lynda"
            stage_1_2()
        
        # information to be disclosed in case the user decides to question richard
        elif "richard" in answer_3:
            print(f""" 
            
        I want to be frank Benoit, Harlan had discovered that I was cheating on his 
        daughter and told me that either I would tell him, or he would. But I would 
        never hurt Harlan, you can ask Marta she knows almost everything.             
            
            """)
            
            # what the user has answered will be transformed only to richard because then it will be used 
            # at the end of stage 1 to send a message to the user of the people you have interrogated. 
            answer_3 = "richard"
            stage_1_2()
        
        # information to be disclosed in case the user decides to question hugh
        elif "hugh" in answer_3:
            print(f""" 
            
            I am the least liked here and I know. But what nobody has told you is that none of 
            the family is part of Harlan's will anymore, and everything will go to Marta, 
            so here the person who had the most to gain was Marta. 
            
            """)
            
            # what the user has answered will be transformed only to hugh because then it will be used 
            # at the end of stage 1 to send a message to the user of the people you have interrogated. 
            answer_3 = "hugh"
            stage_1_2()
        
        # the user is given the option to question Harlan to see if he is attentive. 
        # After reminding him that he is the dead one, he will send him again to choose someone he can interrogate.
        elif "harlan" in answer_3:
            print(f""" 
            
            I'm dead, I can't give you any clues!!! 
            
            """)
            
            answer_3 = "harlan"
            choice_3()
        
        # information to be disclosed in case the user decides to question marta
        elif "marta" in answer_3:
            print(f""" 
            
        I didn't try to kill Harlan but it was my fault. I unintentionally inject 
        Harlan 100 mg from the morphine bottle, instead of Toradol. I didn't have 
        the antidote that is usually in the bag....
            
            """)
            
            # what the user has answered will be transformed only to marta because then it will be used 
            # at the end of stage 1 to send a message to the user of the people you have interrogated. 
            answer_3 = "marta"
            stage_1_2()
        
        # information to be disclosed in case the user decides to question meg
        elif "meg" in answer_3:
            print(f""" 
        
        What can I say? To be honest I don't see my mother Joni killing Harlan 
        just for the college money. As for Marta she is a nice girl, but maybe
        she would be able to kill Harlan, although Hugh may also be able.
            
            """)
        
            # what the user has answered will be transformed only to meg because then it will be used 
            # at the end of stage 1 to send a message to the user of the people you have interrogated. 
            answer_3 = "meg"
            stage_1_2()
        
        # information to be disclosed in case the user decides to question wanetta
        elif "wanetta" in answer_3:
            print(f""" 
        
        Even though I am an older woman I know what I saw the night of the murder.
        In the afternoon I saw Hugh sneak up and down the window. Also, that same 
        night Martha did the same thing. I don't know the motive of both, but I saw what I saw.
            
            """)
            
            # what the user has answered will be transformed only to wanetta because then it will be used 
            # at the end of stage 1 to send a message to the user of the people you have interrogated. 
            answer_3 = "wanetta"
            stage_1_2()
        
        # This is a backdoor that if you enter in any answer the title of the movie 
        # tells you the solution and sends you directly to where you have to solve the murder. 
        # This is not in the instructions and therefore is not taken into account as a possible resolution in a short time. 
        # Even so, I thought it was a good idea to include it in case someone thought of including the title of the movie. 
        elif "knives out" in answer_3:
            print("You have been hired by Hugh Drysdale and Harlan committed suicide. ")
            stage_3()
        
        # If the user does not enter any of the names displayed on the screen, 
        # he will be sent back to the question of whom he wants to question.
        else: 
            print(f""" 
        
        The option entered is not valid, please re-enter a valid option.""")
        
        
            choice_3()
        
# HERE THE FUNCTION OF STAGE 1.2 IS DEFINED.
# At the end of the stage, the user is reminded of the 3 people he/she has questioned. 

def stage_1_2 ():
    
    
    print(f"""
    
    You have questioned {answer_1}, {answer_2}, {answer_3}.
    
    Right now you are one step closer to find who hired you and who killed
    Harlan Thrombey.
    
    """)
    stage_2()

    
# HERE THE FUNCTION OF STAGE 2 IS DEFINED.
#In the second stage the user will be able to acquire more information, 
# in this case not by asking questions, but by choosing between 3 different options. 

def stage_2():
    
    place = input(prompt = "Now, where would yo like to go? Police station, toxicology laboratory or to the house again? \n")
    place = place.lower()
    
    
    # if the user decides to go to the house, he/she will immediately be sent to the third stage.     
    if "house" in place:
        stage_3()
        
    # in case your input enters the word police or station you will be sent to 
    # the police station where you will receive more enlightening clues.
    # Then he/she will again have to choose where you want to go. 
    elif "police" in place or "station" in place:
        print(f"""
            
            After the interrogations carried out we are not very clear 
            who may have killed Harlan, although:

- Marta: has assumed that she made a mistake with the wrong vials when giving 
Harlan the injection, but why would she cut his throat?

- Hugh: had knowledge that none of the family was going to be in the will. He returned 
to the house through the window a little before the time of the murder.

- Harlan: it is possible that he committed suicide so that we would not find out 
that Martha would have killed him otherwise.

- Richard Drysdale: to prevent him from telling his wife that he was cheating on her.

- Joni Thrombey: had run out of money and would not be able to pay for his daughter's college.
            
            """)
        stage_2()
    
    
    # in case the input enters the word toxicology or laboratory he/she will be sent to 
    # the laboratory where he/she will receive more enlightening clues.
    # Then he/she will again have to choose where you want to go.
    elif "toxicology" in place or "laboratory" in place:
        print(f"""
            The toxicology report shows that there was no harmful substance in Harlan's body. 
            That is odd because it is assumed that Martha would have injected him with the 
            wrong medicine. But what if someone switched the vials.
            
            """)
        stage_2()
    
    
    # This is a backdoor that if you enter in any answer the title of the movie 
    # tells you the solution and sends you directly to where you have to solve the murder. 
    # This is not in the instructions and therefore is not taken into account as a possible resolution in a short time. 
    # Even so, I thought it was a good idea to include it in case someone thought of including the title of the movie. 
    elif "knives out" in place:
        print("You have been hired by Hugh Drysdale and Harlan committed suicide. ")
        stage_3()
    
    # in case the user does not enter any of the options given in the question he/she 
    # will be sent back to the question telling him/her that he/she has made a mistake when entering the message. 
    else: 
        print(f"""
        
        {place} does not exist. Look the options carefully.
        
        """)
        stage_2()
    
    
# HERE THE FUNCTION OF STAGE 3 IS DEFINED.
# Here the user will have to decide who has hired him and who has killed Harlan. 
    
def stage_3():
    
    
    # First, the user is told what this stage consists of. 
    
    print(f"""
    
    The decisive moment has arrived. Who hired you (Benoit) and who killed Harlan.
    So let's first try to figure out who hired you. 
    
    """)
    
    # In addition, you are asked which is your favorite number from 1 to 3, 
    # because this will determine the number of attempts you will have.     
    attempts = input(prompt= "First of all, what is your favorite number from 1 to 3? \n")
    
    
    
    
    # while loop created to try to convert the number entered by the user to int format. 
    # In case he/she have not entered a number, and he/she have typed it in,he/she will be sent a message 
    # that it is the wrong format and you will have to re-enter the number. 
    while True:
        try:
            attempts = int(attempts)
            break
        
        except:
            print("Please enter a number in int format. \n")
            attempts = input(prompt= "What is your favorite number from 1 to 3? \n")
    
    
    # In addition, a conditional statement has been created to ensure that the user enters a number between 2 and 4. 
    if attempts < 1 or attempts > 3:
        print("Introduce a number between 1 and 3. \n")
        
        stage_3()
    
    else:
        
        print(f"""Then you will have {attempts} chances to find out who hired you and who killed Harlan.""")
    
        #Finally, a while loop has been created so that until you guess who has hired the detective and 
        # who has killed Harlan, or run out of attempts, it will continue to run. 
        while attempts > 0:
            # here I go to the list created at the beginning to see the options the user have to choose from. 
            employer = input(prompt = f"""Who hired you (Benoit Blanc)?
    
    {suspects [0][1]}
    {suspects [1][1]}
    {suspects [2][1]}
    {suspects [3][1]}
    {suspects [4][1]}
    {suspects [5][1]}
    {suspects [6][1]}
    {suspects [7][1]}
    {suspects [8][1]}
    {suspects [9][1]}
    
    """ )
    
    
            employer = employer.lower()
            
            # here I go to the list created at the beginning to see the options the user have to choose from. 
            killer = input(prompt = f"""Who killed Harlan Thrombey?
    
    {suspects [0][1]}
    {suspects [1][1]}
    {suspects [2][1]}
    {suspects [3][1]}
    {suspects [4][1]}
    {suspects [5][1]}
    {suspects [6][1]}
    {suspects [7][1]}
    {suspects [8][1]}
    {suspects [9][1]}
    
    """ )
        
            killer = killer.lower()
                       
            
            # First, the user is checked to see if he/she can guess who has hired him/her, if so, there are 11 options 
            if "hugh" in employer:
                
                # is also correct that it is Harlan so the while loop is broken.
                if "harlan" in killer:
                    print("You are right.")
                    break
                 
                # correctly enters donna's name so he/she loses one attempt
                elif "donna" in killer:
                    attempts -= 1
            
                    print(f"""You have made a mistake. You have {attempts} attempts left, inspector. """)
                
                # correctly enters joni's name so he/she loses one attempt
                elif "joni" in killer:
                    attempts -= 1

                    print(f"""You have made a mistake. You have {attempts} attempts left, inspector. """)
                
                # correctly enters walt's name so he/she loses one attempt
                elif "walt" in killer:
                    attempts -= 1

                    print(f"""You have made a mistake. You have {attempts} attempts left, inspector. """)
                
                # correctly enters lynda's name so he/she loses one attempt
                elif "lynda" in killer:
                    attempts -= 1

                    print(f"""You have made a mistake. You have {attempts} attempts left, inspector. """)
                
                # correctly enters richard's name so he/she loses one attempt
                elif "richard" in killer:
                    attempts -= 1

                    print(f"""You have made a mistake. You have {attempts} attempts left, inspector. """)
                
                # correctly enters hugh's name so he/she loses one attempt
                elif "hugh" in killer:
                    attempts -= 1

                    print(f"""You have made a mistake. You have {attempts} attempts left, inspector. """)
                
                # correctly enters marta's name so he/she loses one attempt
                elif "marta" in killer:
                    attempts -= 1

                    print(f"""You have made a mistake. You have {attempts} attempts left, inspector. """)
                
                # correctly enters meg's name so he/she loses one attempt
                elif "meg" in killer:
                    attempts -= 1

                    print(f"""You have made a mistake. You have {attempts} attempts left, inspector. """)
                
                # correctly enters wanetta's name so he/she loses one attempt
                elif "wanetta" in killer:
                    attempts -= 1

                    print(f"""You have made a mistake. You have {attempts} attempts left, inspector. """)
                
                # does not write any of the possible options and is asked again for the employer and the killer
                else:
                    print(f"""
                        {killer} is not an option. Make sure you have spelled it right.

                        """)
                
            # it has been proven that his first choice was not hugh now it will be proven 
            # if it is donna, if it is, he/she loses a try. 
            elif "donna" in employer:
                attempts -= 1
            
                print(f"""You have made a mistake. You have {attempts} attempts left, inspector. """)
            
            # it has been proven that his first choice was not hugh now it will be proven 
            # if it is joni, if it is, he/she loses a try.
            elif "joni" in employer:
                attempts -= 1
            
                print(f"""You have made a mistake. You have {attempts} attempts left, inspector. """)
            
            # it has been proven that his first choice was not hugh now it will be proven 
            # if it is walt, if it is, he/she loses a try.
            elif "walt" in employer:
                attempts -= 1
            
                print(f"""You have made a mistake. You have {attempts} attempts left, inspector. """)
            
            # it has been proven that his first choice was not hugh now it will be proven 
            # if it is lynda, if it is, he/she loses a try.
            elif "lynda" in employer:
                attempts -= 1
            
                print(f"""You have made a mistake. You have {attempts} attempts left, inspector. """)
            
            # it has been proven that his first choice was not hugh now it will be proven 
            # if it is richard, if it is, he/she loses a try.
            elif "richard" in employer:
                attempts -= 1
            
                print(f"""You have made a mistake. You have {attempts} attempts left, inspector. """)
            
            # it has been proven that his first choice was not hugh now it will be proven 
            # if it is harlan, if it is, he/she loses a try.
            elif "harlan" in employer:
                attempts -= 1
            
                print(f"""You have made a mistake. You have {attempts} attempts left, inspector. """)
            
            # it has been proven that his first choice was not hugh now it will be proven 
            # if it is marta, if it is, he/she loses a try.
            elif "marta" in employer:
                attempts -= 1
            
                print(f"""You have made a mistake. You have {attempts} attempts left, inspector. """)
            
            # it has been proven that his first choice was not hugh now it will be proven 
            # if it is meg, if it is, he/she loses a try.
            elif "meg" in employer:
                attempts -= 1
            
                print(f"""You have made a mistake. You have {attempts} attempts left, inspector. """)
            
            # it has been proven that his first choice was not hugh now it will be proven 
            # if it is wanetta, if it is, he/she loses a try.
            elif "wanetta" in employer:
                attempts -= 1
            
                print(f"""You have made a mistake. You have {attempts} attempts left, inspector. """)
            
            # does not write any of the possible options and is asked again for the employer and the killer
            else:
                print(f"""
                    {employer} is not an option. Make sure you have spelled it right.
                    
                    """)
               
  
        # Finally, a nested conditional statement has been created that will send the user to the win function 
        # if both answers are correct or to the fail function if the user has run out of attempts. 
        if "hugh" in employer: 
            if "harlan" in killer:
                win()
            else:
                fail()
        elif "hugh" not in employer or "harlan" not in killer:
            fail()

        else:
            print("Something went wrong.")
    
    
# HERE THE WIN FUNCTION IS DEFINED.  
    
def win():
    print(f"""
    Well, it looks like you're as good a detective as they said you were. 
    
      ___________
            '._==_==_=_.'
            .-\:      /-.
           | (|:.     |) |
            '-|:.     |-'
              \::.    /
               '::. .'
                 ) (
               _.' '._
              `"""""""`
    
    """)
    

# HERE THE FAIL FUNCTION IS DEFINED.
def fail():
    print(f"""
          Well, it looks like you weren't as good a detective as they said you were. 
          You have failed, this does not mean that you are a failure in life, but come on, 
          what a detective you are. 
          """)
    
    loser= input(prompt = f"""
    If you want to try again, answer yes. Otherwise, answer no 
    and I will tell you the solution and why.
    """)
    
    loser = loser.lower()
    
    # if the user decides that he/she wants to play again, it is sent back to the beginning.
    if "yes" in loser:
        stage_1_1()
    
    # if the user decides that he/she does not want to play again, the information is disclosed to him/her.
    elif "no" in loser:
        print(f"""
        
        You were hired by Hugh Drysdale because when he found out he would not be part 
        of the inheritance he left his grandfather's birthday party. Then thinking that 
        the only beneficiary would be Martha he knew that if he managed to frame her for 
        Harlan's death she would not be able to receive the inheritance. So she changed 
        the vials so that Martha would be confused when she gave him the medication and 
        took away the antidote so that she could not save him.
        
        The problem is that Martha is such a good nurse that to give him the medication 
        she did not have to look at the name of the medicine, but the slight difference 
        in the color of the contents was enough for her to distinguish it. For this reason, 
        although she took the vial with the wrong label, it contained the right medicine. 
        Yet Harlan and Marta did not realize it in the supposed 10 minutes Harlan had before 
        he died and so Harlan cut his own throat, to defend Marta. 
        
                _____________________________
                           _.-''``------------------------|`. |``''--..__
                      _.-'` ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' | : |          ``'';';--..__
                 _.-'`                                    | : |         '   :';       ```';
            _.-'`                           ________/\_/\_|.'_|_       '   :';           /
       _.-'`                         _.-''``                    ``''--:.__;';           _|
     .'`                        _.-'`                                     `'`''-._     /
   .`                       _.-'                                                  `'-./
 .'                    _.-'`
/               __..-'`
``'''----'''````
        
        
        
        """)
    #if the user does not answer yes or no, he/she is asked again. 
    else:
        print("You should answer yes or no, there are no more options.\n")
        fail()  
            
            
            
stage_1_1()
# Out:
# Inspector Benoit Blanc you will be
# able to interrogate 3 of the following suspects.
#
#
# Donna Thrombey
# Joni Thrombey
# Walt Thrombey
# Lynda Drysdale
# Richard Drysdale
# Hugh Drysdale
# Harlan Thrombey
# Marta Cabrera
# Meg Thrombey
# Wanetta Thrombey
#
#     Who do you want to question first?
#     (enter their first name)
#
#     donna
#
#
#         I'm not interested in this murder and even less in incriminating someone
#         in my family... But if someone stabbed my father had to be Hugh (for me he
#         is not family) or Marta (she is not family at all).
#
#
# Donna Thrombey
# Joni Thrombey
# Walt Thrombey
# Lynda Drysdale
# Richard Drysdale
# Hugh Drysdale
# Harlan Thrombey
# Marta Cabrera
# Meg Thrombey
# Wanetta Thrombey
#
#     Who do you want to be the second lucky person you will question??
#     (enter their first name)
#
#     donna
#
#
#         You have already questioned that person, please show that you
# ...
